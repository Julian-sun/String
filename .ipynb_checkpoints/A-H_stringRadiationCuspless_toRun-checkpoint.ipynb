# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy import integrate
from pylab import *
from sympy.solvers import solve
from sympy import Symbol
from sympy import exp, pi
from scipy.integrate import odeint
from scipy import integrate
import scipy.optimize

from scipy.optimize import minimize
from scipy.optimize import minimize_scalar

import scipy.integrate as integrate
import scipy.special as special

from scipy.special import kn
from scipy import integrate

from scipy.integrate import quad, dblquad
from scipy.integrate import dblquad

from mpmath import nsum, exp, inf

# %%
# !pip install sympy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sympy
#   Downloading sympy-1.11.1-py3-none-any.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 20.9 MB/s eta 0:00:0000:0100:01
# Collecting mpmath>=0.19 (from sympy)
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 7.8 MB/s eta 0:00:0000:01
# Installing collected packages: mpmath, sympy
#   WARNING: The script isympy is installed in '/home/juliane.oliveira/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed mpmath-1.3.0 sympy-1.11.1

# %%
# !pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scipy
#   Downloading scipy-1.10.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 17.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.9/site-packages (from scipy) (1.23.4)
# Installing collected packages: scipy
# Successfully installed scipy-1.10.1
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/juliane.oliveira/.local/lib/python3.9/site-packages (23.0.1)
# Collecting pip
#   Downloading pip-23.1.2-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.0.1
#     Uninstalling pip-23.0.1:
#       Successfully uninstalled pip-23.0.1
#   WARNING: The scripts pip, pip3 and pip3.9 are installed in '/home/juliane.oliveira/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed pip-23.1.2

# %%
def epN(a,theta,phi):
    return np.sin(theta)*np.cos(a/2+phi)

def emN(a,theta,phi):
    return np.sin(theta)*np.cos(a/2-phi)

def emep(a):
    return np.cos(a)

def Cr(a,theta):
    return (np.cos(theta) * np.sin(a))**2

def Dp(n,no,a,theta,phi):
    return (1.0-(-1.0)**n*np.cos( np.pi*n*np.sqrt(1.0-(no/n)**2)*epN(a,theta,phi) ) ) / \
               ( n**2*(1.0-(1.0-(no/n)**2)*epN(a,theta,phi)**2 )**2 )

def Dm(n,no,a,theta,phi):
    return (1.0-(-1.0)**n*np.cos( np.pi*n*np.sqrt(1.0-(no/n)**2)*emN(a,theta,phi) ) ) / \
               ( n**2*(1.0-(1.0-(no/n)**2)*emN(a,theta,phi)**2 )**2 )

def Gn(eta,n,no,a,theta,phi):
    return 2.0/np.pi*eta**2*n**2*np.sqrt(1.0-(no/n)**2)*Dp(n,no,a,theta,phi)*Dm(n,no,a,theta,phi)*\
            Cr(a,theta)*( 1.0 + 2.0*(no/n)**2  )

def GnInt(eta,n,no,a):
    return (dblquad(lambda phi, theta: np.sin(theta)*Gn(eta,n,no,a,theta,phi), \
                                        0, np.pi, lambda x: 0, lambda x: 2*np.pi))


GnSet0 = np.linspace(0,0,100)
NSet = np.linspace(1,100,100)

for i in range(0,100):
    GnSet0[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet0_05pi.out", GnSet0 )


GnSet1 = np.linspace(0,0,100)

for i in range(1,100):
    GnSet1[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet1_05pi.out", GnSet1 )

GnSet2 = np.linspace(0,0,100)

for i in range(2,100):
    GnSet2[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet2_05pi.out", GnSet2 )

GnSet3 = np.linspace(0,0,100)

for i in range(3,100):
    GnSet3[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet3_05pi.out", GnSet3 )

GnSet4 = np.linspace(0,0,100)

for i in range(4,100):
    GnSet4[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet4_05pi.out", GnSet4 )

GnSet5 = np.linspace(0,0,100)

for i in range(5,100):
    GnSet5[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet5_05pi.out", GnSet5 )

GnSet6 = np.linspace(0,0,100)

for i in range(6,100):
    GnSet6[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet6_05pi.out", GnSet6 )

GnSet7 = np.linspace(0,0,100)

for i in range(7,100):
    GnSet7[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet7_05pi.out", GnSet7 )

GnSet8 = np.linspace(0,0,100)

for i in range(8,100):
    GnSet8[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet8_05pi.out", GnSet8 )

GnSet9 = np.linspace(0,0,100)

for i in range(9,100):
    GnSet9[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet9_05pi.out", GnSet9 )

GnSet10 = np.linspace(0,0,100)

for i in range(10,100):
    GnSet10[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet10_05pi.out", GnSet10 )

GnSet15 = np.linspace(0,0,100)

for i in range(15,100):
    GnSet15[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet15_05pi.out", GnSet15 )

GnSet20 = np.linspace(0,0,100)

for i in range(20,100):
    GnSet20[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet20_05pi.out", GnSet20 )

GnSet25 = np.linspace(0,0,100)

for i in range(25,100):
    GnSet25[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet25_05pi.out", GnSet25 )

GnSet30 = np.linspace(0,0,100)

for i in range(30,100):
    GnSet30[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet30_05pi.out", GnSet30 )

GnSet35 = np.linspace(0,0,100)

for i in range(35,100):
    GnSet35[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet35_05pi.out", GnSet35 )

GnSet40 = np.linspace(0,0,100)

for i in range(40,100):
    GnSet40[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet40_05pi.out", GnSet40 )

GnSet45 = np.linspace(0,0,100)

for i in range(45,100):
    GnSet45[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet45_05pi.out", GnSet45 )

GnSet50 = np.linspace(0,0,100)

for i in range(50,100):
    GnSet50[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet50_05pi.out", GnSet50 )

GnSet60 = np.linspace(0,0,100)

for i in range(60,100):
    GnSet60[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet60_05pi.out", GnSet60 )

GnSet70 = np.linspace(0,0,100)

for i in range(70,100):
    GnSet70[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet70_05pi.out", GnSet70 )

GnSet80 = np.linspace(0,0,100)

for i in range(80,100):
    GnSet80[i] = GnInt(1,NSet[i],1.0,np.pi/2)[0]
    
np.savetxt("/home/juliane.oliveira/Documents/GitHub/String/DataGn/GnSet80_05pi.out", GnSet80 )
# Out:
# /home/juliane.oliveira/.local/lib/python3.9/site-packages/scipy/integrate/_quadpack_py.py:1225: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,

# %%
#import time
#start_time = time.time()
#main()
#print("--- %s seconds ---" % (time.time() - start_time))
